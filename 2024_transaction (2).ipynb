# %%
import pandas as pd
data = pd.read_csv('upi_transactions_2024.csv')
data
# Out:
#        transaction id            timestamp transaction type merchant_category  \
# 0       TXN0000000001  2024-11-05 15:30:02              P2P     Entertainment
# 1       TXN0000000002  2024-04-10 12:13:08              P2M           Grocery
# 2       TXN0000000003  2024-04-12 17:59:54              P2P           Grocery
# 3       TXN0000000004  2024-10-22 22:59:54              P2P              Fuel
# 4       TXN0000000005  2024-08-12 12:21:34              P2P          Shopping
# ...               ...                  ...              ...               ...
# 249995  TXN0000249996  2024-03-01 11:30:07         Recharge              Food
# 249996  TXN0000249997  2024-03-31 16:05:06              P2P         Utilities
# 249997  TXN0000249998  2024-09-07 13:41:46              P2P              Food
# 249998  TXN0000249999  2024-06-12 16:14:23         Recharge        Healthcare
# 249999  TXN0000250000  2024-03-01 08:06:38              P2P     Entertainment
#
#         amount (INR) transaction_status sender_age_group receiver_age_group  \
# 0                534            SUCCESS            26-35              26-35
# 1               1951            SUCCESS            26-35              26-35
# 2                388            SUCCESS            26-35              26-35
# 3               1495            SUCCESS            26-35              26-35
# 4               4333            SUCCESS            18-25              26-35
# ...              ...                ...              ...                ...
# 249995          1503            SUCCESS            36-45              36-45
# 249996          1995             FAILED            26-35              18-25
# 249997           370            SUCCESS            26-35              36-45
# 249998           335            SUCCESS            18-25              26-35
# 249999          1130            SUCCESS            26-35              26-35
#
#           sender_state sender_bank receiver_bank device_type network_type  \
# 0            Rajasthan    IndusInd           SBI     Android           4G
# 1       Andhra Pradesh         SBI          Axis     Android           4G
# 2                Delhi       ICICI         Kotak         iOS           4G
# 3            Rajasthan         SBI          Axis     Android           4G
# 4           Tamil Nadu        HDFC          HDFC         iOS           4G
# ...                ...         ...           ...         ...          ...
# 249995  Andhra Pradesh       ICICI           SBI         iOS           5G
# 249996  Andhra Pradesh       ICICI         Kotak     Android           4G
# 249997           Delhi    Yes Bank           SBI     Android           5G
# 249998      Tamil Nadu        HDFC           SBI     Android           5G
# 249999       Telangana       Kotak      IndusInd     Android           4G
#
#         fraud_flag  hour_of_day day_of_week  is_weekend
# 0                0           15     Tuesday           0
# 1                0           12   Wednesday           0
# 2                0           17      Friday           0
# 3                0           22     Tuesday           0
# 4                0           12      Monday           0
# ...            ...          ...         ...         ...
# 249995           0           11      Friday           0
# 249996           0           16      Sunday           1
# 249997           0           13    Saturday           1
# 249998           0           16   Wednesday           0
# 249999           0            8      Friday           0
#
# [250000 rows x 17 columns]

# %%
data.head(2)
# Out:
#   transaction id            timestamp transaction type merchant_category  \
# 0  TXN0000000001  2024-11-05 15:30:02              P2P     Entertainment
# 1  TXN0000000002  2024-04-10 12:13:08              P2M           Grocery
#
#    amount (INR) transaction_status sender_age_group receiver_age_group  \
# 0           534            SUCCESS            26-35              26-35
# 1          1951            SUCCESS            26-35              26-35
#
#      sender_state sender_bank receiver_bank device_type network_type  \
# 0       Rajasthan    IndusInd           SBI     Android           4G
# 1  Andhra Pradesh         SBI          Axis     Android           4G
#
#    fraud_flag  hour_of_day day_of_week  is_weekend
# 0           0           15     Tuesday           0
# 1           0           12   Wednesday           0

# %%
df = pd.read_csv('upi_transactions_2024.csv',usecols = ['timestamp','transaction type','merchant_category','amount (INR)','sender_age_group','receiver_age_group','sender_state','sender_bank','receiver_bank','day_of_week'])
df.head(20)
# Out:
#               timestamp transaction type merchant_category  amount (INR)  \
# 0   2024-11-05 15:30:02              P2P     Entertainment           534
# 1   2024-04-10 12:13:08              P2M           Grocery          1951
# 2   2024-04-12 17:59:54              P2P           Grocery           388
# 3   2024-10-22 22:59:54              P2P              Fuel          1495
# 4   2024-08-12 12:21:34              P2P          Shopping          4333
# 5   2024-11-14 10:17:32              P2P              Food           113
# 6   2024-02-23 19:27:04              P2P             Other           132
# 7   2024-01-14 19:17:30              P2P         Utilities           774
# 8   2024-08-16 11:04:59              P2P             Other           209
# 9   2024-12-09 08:51:32              P2M           Grocery           648
# 10  2024-06-17 20:58:36              P2P              Food           394
# 11  2024-05-16 00:04:26              P2M             Other          1986
# 12  2024-04-02 18:05:15              P2P         Transport           620
# 13  2024-12-07 14:19:02     Bill Payment           Grocery           465
# 14  2024-08-11 09:42:04              P2P         Transport           102
# 15  2024-06-13 22:31:06              P2M           Grocery           293
# 16  2024-06-07 06:47:02              P2P              Food           170
# 17  2024-10-04 16:33:40              P2M        Healthcare           418
# 18  2024-02-27 00:56:34              P2P        Healthcare           214
# 19  2024-12-24 23:11:52              P2P         Utilities           749
#
#    sender_age_group receiver_age_group    sender_state sender_bank  \
# 0             26-35              26-35       Rajasthan    IndusInd
# 1             26-35              26-35  Andhra Pradesh         SBI
# 2             26-35              26-35           Delhi       ICICI
# 3             26-35              26-35       Rajasthan         SBI
# 4             18-25              26-35      Tamil Nadu        HDFC
# 5             18-25              26-35     West Bengal    IndusInd
# 6             18-25              18-25       Karnataka    Yes Bank
# 7             36-45              18-25       Karnataka        HDFC
# 8             26-35              46-55           Delhi         PNB
# 9             26-35              36-45       Karnataka       Kotak
# 10              56+              26-35       Rajasthan       Kotak
# 11            36-45              26-35     Maharashtra         SBI
# 12            26-35              26-35     Maharashtra         PNB
# 13            36-45              18-25           Delhi         PNB
# 14            26-35              18-25     Maharashtra       ICICI
# 15            18-25              26-35   Uttar Pradesh        Axis
# 16            26-35              26-35     West Bengal    IndusInd
# 17            46-55              46-55       Karnataka         PNB
# 18            18-25              18-25       Telangana         SBI
# 19            26-35              26-35     Maharashtra         SBI
#
#    receiver_bank day_of_week
# 0            SBI     Tuesday
# 1           Axis   Wednesday
# 2          Kotak      Friday
# 3           Axis     Tuesday
# 4           HDFC      Monday
# 5           HDFC    Thursday
# 6       IndusInd      Friday
# 7            SBI      Sunday
# 8           HDFC      Friday
# 9          Kotak      Monday
# 10      IndusInd      Monday
# 11           PNB    Thursday
# 12         ICICI     Tuesday
# 13         ICICI    Saturday
# 14      IndusInd      Sunday
# 15         Kotak    Thursday
# 16          HDFC      Friday
# 17          HDFC      Friday
# 18          HDFC     Tuesday
# 19           SBI     Tuesday

# %%
df.isnull().mean()*100
# Out:
# timestamp             0.0
# transaction type      0.0
# merchant_category     0.0
# amount (INR)          0.0
# sender_age_group      0.0
# receiver_age_group    0.0
# sender_state          0.0
# sender_bank           0.0
# receiver_bank         0.0
# day_of_week           0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   timestamp           250000 non-null  object
#  1   transaction type    250000 non-null  object
#  2   merchant_category   250000 non-null  object
#  3   amount (INR)        250000 non-null  int64
#  4   sender_age_group    250000 non-null  object
#  5   receiver_age_group  250000 non-null  object
#  6   sender_state        250000 non-null  object
#  7   sender_bank         250000 non-null  object
#  8   receiver_bank       250000 non-null  object
#  9   day_of_week         250000 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 19.1+ MB

# %%
df.columns
# Out:
# Index(['timestamp', 'transaction type', 'merchant_category', 'amount (INR)',
#        'sender_age_group', 'receiver_age_group', 'sender_state', 'sender_bank',
#        'receiver_bank', 'day_of_week'],
#       dtype='object')

# %%
df.dtypes
# Out:
# timestamp             object
# transaction type      object
# merchant_category     object
# amount (INR)           int64
# sender_age_group      object
# receiver_age_group    object
# sender_state          object
# sender_bank           object
# receiver_bank         object
# day_of_week           object
# dtype: object

# %%
df.describe()
# Out:
#         amount (INR)
# count  250000.000000
# mean     1247.434336
# std      1667.195776
# min        10.000000
# 25%       281.000000
# 50%       603.000000
# 75%      1551.000000
# max     43424.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   timestamp           250000 non-null  object
#  1   transaction type    250000 non-null  object
#  2   merchant_category   250000 non-null  object
#  3   amount (INR)        250000 non-null  int64
#  4   sender_age_group    250000 non-null  object
#  5   receiver_age_group  250000 non-null  object
#  6   sender_state        250000 non-null  object
#  7   sender_bank         250000 non-null  object
#  8   receiver_bank       250000 non-null  object
#  9   day_of_week         250000 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 19.1+ MB

# %%
df.head()
# Out:
#              timestamp transaction type merchant_category  amount (INR)  \
# 0  2024-11-05 15:30:02              P2P     Entertainment           534
# 1  2024-04-10 12:13:08              P2M           Grocery          1951
# 2  2024-04-12 17:59:54              P2P           Grocery           388
# 3  2024-10-22 22:59:54              P2P              Fuel          1495
# 4  2024-08-12 12:21:34              P2P          Shopping          4333
#
#   sender_age_group receiver_age_group    sender_state sender_bank  \
# 0            26-35              26-35       Rajasthan    IndusInd
# 1            26-35              26-35  Andhra Pradesh         SBI
# 2            26-35              26-35           Delhi       ICICI
# 3            26-35              26-35       Rajasthan         SBI
# 4            18-25              26-35      Tamil Nadu        HDFC
#
#   receiver_bank day_of_week
# 0           SBI     Tuesday
# 1          Axis   Wednesday
# 2         Kotak      Friday
# 3          Axis     Tuesday
# 4          HDFC      Monday

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.shape
# Out:
# (250000, 10)

# %%
df['receiver_age_group'].nunique()
# Out:
# 5

# %%
df['sender_age_group'].value_counts()
# Out:
# sender_age_group
# 26-35    88149
# 36-45    62252
# 18-25    62088
# 46-55    24908
# 56+      12603
# Name: count, dtype: int64

# %%
df['receiver_age_group'].value_counts()
# Out:
# receiver_age_group
# 26-35    87735
# 36-45    62671
# 18-25    62101
# 46-55    25022
# 56+      12471
# Name: count, dtype: int64

# %%
df['transaction type'].value_counts()
# Out:
# transaction type
# P2P             112445
# P2M              87660
# Bill Payment     37368
# Recharge         12527
# Name: count, dtype: int64

# %%
df['receiver_age_group'] = df['receiver_age_group'].replace({'18-25':'A','26-35':'B','36-45':'C','46-55':'D','56+':'E'})

# %%
df['sender_age_group'] = df['sender_age_group'].replace({'18-25':'A','26-35':'B','36-45':'C','46-55':'D','56+':'E'})

# %%
df.head()
# Out:
#             timestamp transaction type merchant_category  amount (INR)  \
# 0 2024-11-05 15:30:02              P2P     Entertainment           534
# 1 2024-04-10 12:13:08              P2M           Grocery          1951
# 2 2024-04-12 17:59:54              P2P           Grocery           388
# 3 2024-10-22 22:59:54              P2P              Fuel          1495
# 4 2024-08-12 12:21:34              P2P          Shopping          4333
#
#   sender_age_group receiver_age_group    sender_state sender_bank  \
# 0                B                  B       Rajasthan    IndusInd
# 1                B                  B  Andhra Pradesh         SBI
# 2                B                  B           Delhi       ICICI
# 3                B                  B       Rajasthan         SBI
# 4                A                  B      Tamil Nadu        HDFC
#
#   receiver_bank day_of_week
# 0           SBI     Tuesday
# 1          Axis   Wednesday
# 2         Kotak      Friday
# 3          Axis     Tuesday
# 4          HDFC      Monday

# %%
df['merchant_category'].value_counts()
# Out:
# merchant_category
# Grocery          49966
# Food             37464
# Shopping         29872
# Fuel             25063
# Other            24828
# Utilities        22338
# Transport        20105
# Entertainment    20103
# Healthcare       12663
# Education         7598
# Name: count, dtype: int64

# %%
df['sender_state'].value_counts()
# Out:
# sender_state
# Maharashtra       37596
# Uttar Pradesh     30186
# Karnataka         29814
# Tamil Nadu        25232
# Delhi             25118
# Telangana         22251
# Andhra Pradesh    20092
# West Bengal       19935
# Gujarat           19898
# Rajasthan         19878
# Name: count, dtype: int64

# %%
df['sender_bank'].value_counts()
# Out:
# sender_bank
# SBI         62759
# HDFC        37317
# ICICI       30003
# PNB         25031
# Yes Bank    24988
# Axis        24842
# IndusInd    24785
# Kotak       20275
# Name: count, dtype: int64

# %%
df['receiver_bank'].value_counts()
# Out:
# receiver_bank
# SBI         62205
# HDFC        37724
# ICICI       30064
# Axis        25067
# IndusInd    25066
# Yes Bank    25062
# PNB         25003
# Kotak       19809
# Name: count, dtype: int64

# %%
df['day_of_week'].value_counts()
# Out:
# day_of_week
# Monday       36525
# Sunday       35813
# Friday       35811
# Wednesday    35629
# Saturday     35605
# Tuesday      35483
# Thursday     35134
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#             timestamp transaction type merchant_category  amount (INR)  \
# 0 2024-11-05 15:30:02              P2P     Entertainment           534
# 1 2024-04-10 12:13:08              P2M           Grocery          1951
#
#   sender_age_group receiver_age_group    sender_state sender_bank  \
# 0                B                  B       Rajasthan    IndusInd
# 1                B                  B  Andhra Pradesh         SBI
#
#   receiver_bank day_of_week
# 0           SBI     Tuesday
# 1          Axis   Wednesday

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(7, 6))
sns.countplot(data=df, x='sender_state', hue='sender_age_group')
plt.title('Transaction Count by Sender State and Age Group')
plt.xlabel('Sender State')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['year_month'] = df['timestamp'].dt.to_period('M').astype(str)
monthly_amount = df.groupby(['year_month', 'merchant_category'])['amount (INR)'].sum().reset_index()
plt.figure(figsize=(14,7))
sns.lineplot(data=monthly_amount, x='year_month', y='amount (INR)', hue='merchant_category', marker='o')
plt.xticks(rotation=45)
#plt.title('Monthly Total Amount by Merchant Category')
plt.xlabel('Month')
plt.ylabel('Total Amount (INR)')
plt.legend(title='Merchant Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
pivot_table = monthly_amount.pivot(index='merchant_category', columns='year_month', values='amount (INR)')

plt.figure(figsize=(12,5))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap='YlOrRd')
#plt.title('Heatmap of Total Amount by Merchant Category and Month')
plt.xlabel('Month')
plt.ylabel('Merchant Category')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df, x='merchant_category', hue='receiver_age_group')
plt.xticks(rotation=45)
#plt.title('Count of Receiver Age Groups by Merchant Category')
plt.tight_layout()
plt.show()

# %%
cross_tab = pd.crosstab(df['merchant_category'], df['receiver_age_group'])

plt.figure(figsize=(10,6))
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Heatmap of Merchant Category vs receiver Age Group')
plt.ylabel('Merchant Category')
plt.xlabel('receiver Age Group')
plt.show()

# %%
sns.countplot(data=df, x='merchant_category', hue='sender_age_group')
plt.xticks(rotation=45)
#plt.title('Count of Sender Age Groups by Merchant Category')
plt.tight_layout()
plt.show()

# %%
cross_tab = pd.crosstab(df['merchant_category'], df['sender_age_group'])

plt.figure(figsize=(10,6))
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Heatmap of Merchant Category vs Sender Age Group')
plt.ylabel('Merchant Category')
plt.xlabel('Sender Age Group')
plt.show()

# %%
sns.barplot(x='merchant_category', y='amount (INR)', data=df, color='orange', errorbar=None)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.countplot(x = 'receiver_age_group', data=df,color='orange')
# Out:
# <Axes: xlabel='receiver_age_group', ylabel='count'>

# %%
sns.countplot(x = 'transaction type', data=df,color='orange',width=0.35)
# Out:
# <Axes: xlabel='transaction type', ylabel='count'>

# %%
transaction_counts = df['transaction type'].value_counts()
plt.figure(figsize=(5, 4))
plt.pie(transaction_counts, labels=transaction_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
#plt.title('Transaction Type Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie is circular
plt.tight_layout()
plt.show()

# %%
amount_by_state = df.groupby('sender_state')['amount (INR)'].sum()
plt.pie(
    amount_by_state,                
    labels=amount_by_state.index,  
    autopct='%1.1f%%',             
    startangle=90                   
)
#plt.title('Amount (INR) Distribution by Sender State')
plt.axis('equal') 
plt.show()

# %%
amount_by_sender_bank = df.groupby('sender_bank')['amount (INR)'].sum()

plt.pie(
    amount_by_sender_bank,                
    labels=amount_by_sender_bank.index,  
    autopct='%1.1f%%',             
    startangle=90                   
)
#plt.title('Amount (INR) Distribution by Sender Bank')
plt.axis('equal') 
plt.show()

# %%
amount_by_receiver_bank = df.groupby('receiver_bank')['amount (INR)'].sum()

plt.pie(
    amount_by_receiver_bank,                
    labels=amount_by_receiver_bank.index,   # corrected here
    autopct='%1.1f%%',             
    startangle=90                   
)
#plt.title('Amount (INR) Distribution by receiver bank')
plt.axis('equal') 
plt.show()

# %%
df.head(2)
# Out:
#             timestamp transaction type merchant_category  amount (INR)  \
# 0 2024-11-05 15:30:02              P2P     Entertainment           534
# 1 2024-04-10 12:13:08              P2M           Grocery          1951
#
#   sender_age_group receiver_age_group    sender_state sender_bank  \
# 0                B                  B       Rajasthan    IndusInd
# 1                B                  B  Andhra Pradesh         SBI
#
#   receiver_bank day_of_week year_month
# 0           SBI     Tuesday    2024-11
# 1          Axis   Wednesday    2024-04

# %%
df['amount (INR)'].describe()
# Out:
# count    250000.000000
# mean       1247.434336
# std        1667.195776
# min          10.000000
# 25%         281.000000
# 50%         603.000000
# 75%        1551.000000
# max       43424.000000
# Name: amount (INR), dtype: float64

# %%
df['transaction type'].value_counts()
# Out:
# transaction type
# P2P             112445
# P2M              87660
# Bill Payment     37368
# Recharge         12527
# Name: count, dtype: int64

# %%
df['day'] = df['timestamp'].dt.day_name() 
df['day'].value_counts().sort_index()
# Out:
# day
# Friday       35811
# Monday       36525
# Saturday     35605
# Sunday       35813
# Thursday     35134
# Tuesday      35483
# Wednesday    35629
# Name: count, dtype: int64

# %%
df['day'].value_counts().sort_index()
sns.countplot(x='day', data=df,colour = 'orange')
#plt.title("Transaction Count by day")
plt.xlabel("day")
plt.ylabel("Number of Transactions")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 df['day'].value_counts().sort_index()
# ----> 2 sns.countplot(x='day', data=df,colour = 'orange')
#       3 #plt.title("Transaction Count by day")
#       4 plt.xlabel("day")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:2661, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2659 saturation = saturation if fill else 1
#    2660 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2661 color = _default_color(ax.bar, hue, color, kwargs, saturation)
#    2663 count_axis = {"x": "y", "y": "x"}[p.orient]
#    2664 if p.input_format == "wide":
#
# File ~\AppData\Roaming\Python\Python312\site-packages\seaborn\utils.py:127, in _default_color(method, hue, color, kws, saturation)
#     122     scout.remove()
#     124 elif method.__name__ == "bar":
#     125
#     126     # bar() needs masked, not empty data, to generate a patch
# --> 127     scout, = method([np.nan], [np.nan], **kws)
#     128     color = to_rgb(scout.get_facecolor())
#     129     scout.remove()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_axes.py:2654, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2645 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2646     r = mpatches.Rectangle(
#    2647         xy=(l, b), width=w, height=h,
#    2648         facecolor=c,
#    (...)
#    2652         hatch=htch,
#    2653         )
# -> 2654     r._internal_update(kwargs)
#    2655     r.get_path()._interpolation_steps = 100
#    2656     if orientation == 'vertical':
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'colour'

# %%
# df['day'] = df['timestamp'].dt.day 
# df['day'].value_counts().sort_index()
# sns.countplot(x='day', data=df)
# plt.title("Transaction Count by day")
# plt.xlabel("day")
# plt.ylabel("Number of Transactions")
# plt.tight_layout()
# plt.show()

# %%
heatmap_data = df.pivot_table(index='sender_state', columns='sender_age_group', values='amount (INR)', aggfunc='sum')
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu')

# %%
df['month'] = df['timestamp'].dt.strftime('%B')
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']
sns.countplot(x='month', data=df, order=month_order, color='orange')
plt.title("Monthly Transaction Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
